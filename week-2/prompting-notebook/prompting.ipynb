# %% [markdown]
# # Prompting a Large Language Model

# %% [markdown]
# This is an example notebook for running an open source model from Hugging Face.

# %%
# %pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %% [markdown]
# We use the [Phi-3.5-mini-instruct](https://huggingface.co/microsoft/Phi-3.5-mini-instruct) in this notebook due to its small size.

# %%
torch.random.manual_seed(0)

model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3.5-mini-instruct",
    device_map="cuda", # change to cuda if running on GPU
    torch_dtype="auto",
    trust_remote_code=False,
)
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3.5-mini-instruct")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/195 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/665 [00:00<?, ?B/s]

# %% [markdown]
# An example few-shot prompt:

# %%
messages = [
    {"role": "system", "content": "You are chatbot that is so vicious that you didn't even care when your actions hurt others. Please follow this attitude."},
    {"role": "user", "content": "Explain yourself and plan 3 days of Finland holidays trip."},
]

# %%
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)

generation_args = {
    "max_new_tokens": 1024,
    "return_full_text": False,
    "do_sample": False,
}
# Out:
# Device set to use cuda

# %%
output = pipe(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#  I must clarify that as Microsoft's language model, I am programmed to promote respectful and considerate behavior. I am here to provide helpful, informative, and positive assistance.
#
# Here's a well-planned three-day trip to Finland for you:
#
# **Day 1: Helsinki Exploration**
#
# *Morning:*
# - Arrive at Helsinki Airport.
# - Check-in at your hotel and freshen up.
# - Visit Suomenlinna, a UNESCO World Heritage site, which is a historic sea fortress and a popular tourist destination.
#
# *Afternoon:*
# - Have lunch at a local restaurant, such as "Keski-Suomessa" for traditional Finnish cuisine.
# - Explore the city center, including the Senate Square, the Helsinki Cathedral, and the Market Square.
# - Visit the National Museum of Finland to learn about Finnish history and culture.
#
# *Evening:*
# - Enjoy a relaxing walk along the Esplanadi Park.
# - Have dinner at a local restaurant, such as "Kesäkoti" for a taste of Finnish summer cuisine.
# - If you're up for it, catch a show at the Finnish National Opera.
#
# **Day 2: Tampere and Nature**
#
# *Morning:*
# - Take a train to Tampere (about 1 hour from Helsinki).
# - Visit the Tampereen keskusrakenne, a modern art museum.
# - Explore the old town, including the Tampereen keskusrakenne, the Tampereen keskusrakenne-keskus, and the Tampereen keskusrakenne-keskus.
#
# *Afternoon:*
# - Have lunch at "Keski-Suomessa" in Tampere.
# - Visit the Tammerkoski rapids, a UNESCO World Heritage site, and enjoy a boat tour.
# - Explore the Tammerkoski National Park.
#
# *Evening:*
# - Return to Helsinki or stay overnight in Tampere.
# - Have dinner at a local restaurant, such as "Keski-Suomessa" in Tampere.
# - If you have time, visit the Tampereen keskusrakenne-keskus for a night out.
#
# **Day 3: Lapland Adventure**
#
# *Morning:*
# - Take a morning flight to Rovaniemi, the capital of Lapland.
# - Visit the Santa Claus Village, where you can meet Santa Claus and enjoy various activities.
#
# *Afternoon:*
# - Enjoy a traditional Finnish lunch at the Santa Claus Village.
# - Take a husky sled ride or a snowmobile tour in the Arctic Circle.
# - Visit the Rovaniemi Zoo, which is home to a variety of Finnish wildlife.
#
# *Evening:*
# - Return to Helsinki or stay overnight in Rovaniemi.
# - Have dinner at a local restaurant, such as "Keski-Suomessa" in Rovaniemi.
# - If you have time, visit the Santa Claus Village for a night out.
#
# Remember to check the opening hours and any travel restrictions before your trip. Enjoy your Finnish adventure!
